# %% [markdown]
# # Steps
#
# # 0. Preprocess + EDA + Feature Selection
# # 1. Extract input and output cols
# # 2. Scale the values
# # 3. Train test split
# # 4. Train the model
# # 5. Evaluate the model/model selection
# # 6. Deploy the model

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/placement.csv")
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df = df.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #EDA -> It give idea about the data , we can use diagrams library to get a proper idea ..

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %% [markdown]
# #Extract Input and Output columns

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,2:] # or iloc[:,-1]

# %%
y
# Out:
#     placement
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# ..        ...
# 95          0
# 96          0
# 97          1
# 98          1
# 99          1
#
# [100 rows x 1 columns]

# %% [markdown]
# #Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
y_train
# Out:
#     placement
# 66          1
# 53          1
# 28          0
# 59          0
# 15          0
# ..        ...
# 42          1
# 17          0
# 25          0
# 81          0
# 30          1
#
# [90 rows x 1 columns]

# %%
X_train
# Out:
#     cgpa     iq
# 66   6.9   96.0
# 53   8.3  168.0
# 28   5.2   90.0
# 59   4.8  112.0
# 15   5.1  176.0
# ..   ...    ...
# 42   7.6   89.0
# 17   3.3  183.0
# 25   5.0   91.0
# 81   5.4  107.0
# 30   7.6  128.0
#
# [90 rows x 2 columns]

# %% [markdown]
# #Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.80257595, -0.69262436],
#        [ 2.02684435,  1.18450064],
#        [-0.68403568, -0.84905145],
#        [-1.03382665, -0.27548547],
#        [-0.77148342,  1.39307008],
#        [ 0.01554627, -2.02225457],
#        [-0.77148342, -1.47475978],
#        [ 0.71512821,  0.01129751],
#        [-0.24679696,  0.24593814],
#        [-1.03382665,  1.21057182],
#        [ 0.80257595,  0.4284364 ],
#        [ 1.15236692,  0.37629404],
#        [ 0.80257595,  0.40236522],
#        [-0.24679696,  0.45450758],
#        [ 1.32726241,  0.92378883],
#        [ 0.27788949, -0.5101261 ],
#        [-1.12127439, -1.83975631],
#        [-0.24679696,  1.21057182],
#        [ 1.32726241,  0.19379578],
#        [ 0.10299401, -1.50083096],
#        [-0.68403568,  1.00200237],
#        [-0.85893116, -1.55297332],
#        [ 0.27788949,  0.14165341],
#        [ 0.89002369,  0.4284364 ],
#        [-2.1706473 ,  2.87912738],
#        [-0.50914019,  0.4284364 ],
#        [ 0.54023272,  0.40236522],
# ...

# %%
X_test=scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-1.17306314,  0.16726224],
#        [ 0.58191321,  0.42923924],
#        [ 0.85901474, -1.3844477 ],
#        [-1.08069596,  0.44939132],
#        [ 1.87505368,  0.67106417],
#        [-0.06465702, -0.17532307],
#        [-0.80359443,  1.83988464],
#        [-1.26543031, -0.2357793 ],
#        [ 0.39717886, -1.92855378],
#        [ 0.67428039,  0.16726224]])

# %%
X_test
# Out:
# array([[-1.17306314,  0.16726224],
#        [ 0.58191321,  0.42923924],
#        [ 0.85901474, -1.3844477 ],
#        [-1.08069596,  0.44939132],
#        [ 1.87505368,  0.67106417],
#        [-0.06465702, -0.17532307],
#        [-0.80359443,  1.83988464],
#        [-1.26543031, -0.2357793 ],
#        [ 0.39717886, -1.92855378],
#        [ 0.67428039,  0.16726224]])

# %% [markdown]
# #Model Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
y_train

# %%
#model trainging
clf.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
y_new=y_train.values.ravel()

# %%
plot_decision_regions(X_train,y_new,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.plk','wb'))
